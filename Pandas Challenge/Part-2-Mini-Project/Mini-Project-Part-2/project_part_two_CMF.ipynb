# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csvpath= "Resources/Survey_Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file
df = pd.read_csv(csvpath, encoding = 'utf8')
df.head()
# Out:
# C:\Users\cfing\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Consider using iloc
df = df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
df["AttendedBootcamp"] = df["AttendedBootcamp"].replace({0:'No', 1:'Yes'})
df
# Out:
#         Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               No             NaN                   NaN
# 1      22.0               No             NaN                   NaN
# 2      19.0               No             NaN                   NaN
# 3      26.0               No             NaN                   NaN
# 4      20.0               No             NaN                   NaN
# ...     ...              ...             ...                   ...
# 15615  39.0               No             NaN                   NaN
# 15616  27.0               No             NaN                   NaN
# 15617  37.0               No             NaN                   NaN
# 15618  26.0               No             NaN                   NaN
# 15619  22.0               No             NaN                   NaN
#
#        BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                    NaN          NaN                 NaN                NaN
# ...

# %%
# Extract rows for only those who attended a bootcamp
length= len(bootcamp_attendee_df)
bootcamp_attendee_df= df.loc[df["AttendedBootcamp"]== 'Yes']
bootcamp_attendee_df
# Out:
#         Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 93     32.0              Yes             1.0                   0.0
# 97     26.0              Yes             1.0                   1.0
# 130    41.0              Yes             1.0                   1.0
# 159    26.0              Yes             1.0                   0.0
# 188    24.0              Yes             0.0                   NaN
# ...     ...              ...             ...                   ...
# 15539  39.0              Yes             1.0                   1.0
# 15540  24.0              Yes             1.0                   1.0
# 15541  23.0              Yes             1.0                   1.0
# 15593  29.0              Yes             0.0                   NaN
# 15600  28.0              Yes             1.0                   1.0
#
#        BootcampLoanYesNo              BootcampName  BootcampPostSalary  \
# 93                   0.0            Codify Academy                 NaN
# ...

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
# Create a DataFrame from using value_counts
attend_df= bootcamp_attendee_df.groupby(["BootcampName" ]).count()
enrollees= attend_df["AttendedBootcamp"]

enrollees_df= pd.DataFrame ({"Enrollees": enrollees})



enrollees_df
# Out:
#                        Enrollees
# BootcampName
# 10x.org.il                     5
# 4Geeks Academy                 8
# AcadGild                       2
# Academia de Código             4
# Academic Work Academy          1
# ...                          ...
# Wyncode                        6
# Zip Code Wilmington            3
# codeU                          1
# devCodeCamp                    4
# tradecraft                     3
#
# [128 rows x 1 columns]

# %% [raw]
# # Count how many attendees of each bootcamp would recommend the bootcamp

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp

recommend_df = bootcamp_attendee_df.groupby(["BootcampName"]).sum()["BootcampRecommend"]
recommend_df

recs_df= pd.DataFrame ({"Recommenders": recommend_df})
recs_df
# Out:
#                        Recommenders
# BootcampName
# 10x.org.il                      3.0
# 4Geeks Academy                  4.0
# AcadGild                        2.0
# Academia de Código              4.0
# Academic Work Academy           0.0
# ...                             ...
# Wyncode                         3.0
# Zip Code Wilmington             1.0
# codeU                           1.0
# devCodeCamp                     4.0
# tradecraft                      1.0
#
# [128 rows x 1 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp

combined_df= pd.merge(enrollees_df, recs_df, on= ["BootcampName"])
combined_df

sorted_summary= combined_df.sort_values("Enrollees", ascending= False)
sorted_summary
# Out:
#                          Enrollees  Recommenders
# BootcampName
# General Assembly                90          70.0
# Flatiron School                 54          50.0
# Dev Bootcamp                    48          41.0
# The Iron Yard                   40          31.0
# Prime Digital Academy           30          25.0
# ...                            ...           ...
# Ruby On The Beach                1           1.0
# Code Union                       1           1.0
# Science to Data Science          1           1.0
# SeedPaths                        1           1.0
# Base10 Academy                   1           1.0
#
# [128 rows x 2 columns]

# %%
# Calculate percentage of each bootcamp's students who are recommenders
# Think of what should be the numerator and the demoninator
sorted_summary["% Recommend"]= sorted_summary["Recommenders"] / sorted_summary["Enrollees"]
sorted_summary
# Sort results in descending order

sorted_summary= sorted_summary.sort_values("% Recommend", ascending = False)
sorted_summary                                           
# Format for percentages
sorted_summary["% Recommend"]= sorted_summary["% Recommend"].map("{:.2%}".format)

sorted_summary
final_table= sorted_summary.reset_index()
final_table
# Out:
#               BootcampName  Enrollees  Recommenders % Recommend
# 0             Grand Circus          3           3.0     100.00%
# 1       The Data Incubator          1           1.0     100.00%
# 2            Coder Foundry          1           1.0     100.00%
# 3              DESIGNATION          1           1.0     100.00%
# 4                    codeU          1           1.0     100.00%
# ..                     ...        ...           ...         ...
# 123               Alphappl          1           0.0       0.00%
# 124      World Tech Makers          1           0.0       0.00%
# 125  Academic Work Academy          1           0.0       0.00%
# 126           Atlanta Code          1           0.0       0.00%
# 127         DaVinci Coders          2           0.0       0.00%
#
# [128 rows x 4 columns]

# %%
# Export to excel and remove index
final_table.to_excel ("output/BootcampOutputPart2.xlsx", index = False)
